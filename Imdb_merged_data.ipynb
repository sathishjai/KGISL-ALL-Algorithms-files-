# %%
import pandas as pd

# %%
df1=pd.read_csv('/home/sathish/Downloads/merged_data1.csv')
df1
# Out:
#            ImdbId  ...                                               cast
# 0      tt10648440  ...  [{'name': 'Jo Jung-Suk', 'name_id': 'nm4983186...
# 1       tt5253282  ...  [{'name': 'J.K. Simmons', 'name_id': 'nm079977...
# 2       tt0072752  ...  [{'name': 'Sirpa Lane', 'name_id': 'nm0485562'...
# 3       tt0037954  ...  [{'name': 'Errol Flynn', 'name_id': 'nm0001224...
# 4       tt6399158  ...  [{'name': 'Ji Chang-Wook', 'name_id': 'nm38656...
# ...           ...  ...                                                ...
# 10245   tt0176102  ...  [{'name': 'Joseph Di Mambro', 'name_id': 'nm02...
# 10246   tt0171957  ...  [{'name': 'Andrey Kharitonov', 'name_id': 'nm0...
# 10247   tt0170091  ...  [{'name': 'Gábor Harsányi', 'name_id': 'nm0366...
# 10248   tt0169775  ...  [{'name': 'Ján Rohác', 'name_id': 'nm0737631'}...
# 10249   tt0169204  ...  [{'name': 'Ali Allen', 'name_id': 'nm0020252'}...
#
# [10250 rows x 13 columns]

# %%
list_values = df['cast'].tolist()
new_df = pd.DataFrame({'cast': list_values})

# %%
new_df
# Out:
#                                                     cast
# 0      [{'name': 'Jo Jung-Suk', 'name_id': 'nm4983186...
# 1      [{'name': 'J.K. Simmons', 'name_id': 'nm079977...
# 2      [{'name': 'Sirpa Lane', 'name_id': 'nm0485562'...
# 3      [{'name': 'Errol Flynn', 'name_id': 'nm0001224...
# 4      [{'name': 'Ji Chang-Wook', 'name_id': 'nm38656...
# ...                                                  ...
# 10245  [{'name': 'Joseph Di Mambro', 'name_id': 'nm02...
# 10246  [{'name': 'Andrey Kharitonov', 'name_id': 'nm0...
# 10247  [{'name': 'Gábor Harsányi', 'name_id': 'nm0366...
# 10248  [{'name': 'Ján Rohác', 'name_id': 'nm0737631'}...
# 10249  [{'name': 'Ali Allen', 'name_id': 'nm0020252'}...
#
# [10250 rows x 1 columns]

# %%
lists = new_df

counts = [len(lst) for lst in lists]

print(counts)
# Out:
# [4]

# %%
import pandas as pd

# Create a sample DataFrame
data =dg
df = pd.DataFrame(data)

# Define a function to apply to each row
# Define a function to apply to each row

def apply_function(row):

    return len((row)


# Apply the function to each row

df['result'] = df.apply(apply_function, axis=1)


print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 17
#      12     return len(count(row))
#      15 # Apply the function to each row
# ---> 17 df['result'] = df.apply(apply_function, axis=1)
#      20 print(df)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# ...

# %%
dg=df["cast"]

# %%
dg
# Out:
# 0        [{'name': 'Jo Jung-Suk', 'name_id': 'nm4983186...
# 1        [{'name': 'J.K. Simmons', 'name_id': 'nm079977...
# 2        [{'name': 'Sirpa Lane', 'name_id': 'nm0485562'...
# 3        [{'name': 'Errol Flynn', 'name_id': 'nm0001224...
# 4        [{'name': 'Ji Chang-Wook', 'name_id': 'nm38656...
#                                ...
# 10245    [{'name': 'Joseph Di Mambro', 'name_id': 'nm02...
# 10246    [{'name': 'Andrey Kharitonov', 'name_id': 'nm0...
# 10247    [{'name': 'Gábor Harsányi', 'name_id': 'nm0366...
# 10248    [{'name': 'Ján Rohác', 'name_id': 'nm0737631'}...
# 10249    [{'name': 'Ali Allen', 'name_id': 'nm0020252'}...
# Name: cast, Length: 10250, dtype: object

# %%
import pandas as pd

# Create a sample DataFrame
data = dg
df = pd.DataFrame(data)

# Define a function to count the number of values in each row
def count_values(row):

    comma_count = 1

    for s in row.values:

        if isinstance(s, str):

            comma_count += s.count(',')

    return comma_count

#print(ctr)

# Apply the function to each row
df['count'] = df.apply(count_values, axis=1)

print(df)
# Out:
#                                                     cast  count
# 0      [{'name': 'Jo Jung-Suk', 'name_id': 'nm4983186...      8
# 1      [{'name': 'J.K. Simmons', 'name_id': 'nm079977...      8
# 2      [{'name': 'Sirpa Lane', 'name_id': 'nm0485562'...      8
# 3      [{'name': 'Errol Flynn', 'name_id': 'nm0001224...      8
# 4      [{'name': 'Ji Chang-Wook', 'name_id': 'nm38656...      8
# ...                                                  ...    ...
# 10245  [{'name': 'Joseph Di Mambro', 'name_id': 'nm02...      8
# 10246  [{'name': 'Andrey Kharitonov', 'name_id': 'nm0...      8
# 10247  [{'name': 'Gábor Harsányi', 'name_id': 'nm0366...      8
# 10248  [{'name': 'Ján Rohác', 'name_id': 'nm0737631'}...     10
# 10249  [{'name': 'Ali Allen', 'name_id': 'nm0020252'}...      8
#
# [10250 rows x 2 columns]

# %%
df = df.rename(columns={ImdbId 	_id 	name 	poster_url 	year 	certificate 	runtime 	genre 	ratingValue 	summary_text 	ratingCount","director":"","cast'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ' director'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 dg1=df[' director']
#
# ...
