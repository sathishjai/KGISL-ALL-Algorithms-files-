# %%
import pandas as pd

# %%
df=pd.read_csv('/home/sathish/Documents/IDCJAC0001_022837_Data12.csv')
df
# Out:
#    Product code  Station Number  Year   Jan  ...    Oct   Nov   Dec  Annual
# 0    IDCJAC0001           22837  1978   NaN  ...   28.5  15.0  13.0     NaN
# 1    IDCJAC0001           22837  1980   5.0  ...   81.5  30.5  30.5   632.0
# 2    IDCJAC0001           22837  1981  31.0  ...   24.0  16.0   0.0   707.5
# 3    IDCJAC0001           22837  1982  11.5  ...   18.5   0.0   8.0   457.0
# 4    IDCJAC0001           22837  1983   4.5  ...   34.0  34.0  27.0   913.5
# 5    IDCJAC0001           22837  1984   NaN  ...    NaN   NaN  15.8     NaN
# 6    IDCJAC0001           22837  1985   7.8  ...   48.3  13.2  28.0   641.6
# 7    IDCJAC0001           22837  1986   0.0  ...   59.2  15.8  64.8   680.8
# 8    IDCJAC0001           22837  1987   1.8  ...   55.8   1.8  36.6   532.1
# 9    IDCJAC0001           22837  1988  44.0  ...   15.4  45.8  12.2   652.4
# 10   IDCJAC0001           22837  1989   5.2  ...   45.2  17.0   0.0   741.2
# ...
