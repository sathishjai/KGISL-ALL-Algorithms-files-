# %%
import requests

url="https://www.airbnb.co.in/?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&search_mode=flex_destinations_search&flexible_trip_lengths%5B%5D=one_week&location_search=MIN_MAP_BOUNDS&monthly_start_date=2024-10-01&monthly_length=3&monthly_end_date=2025-01-01&price_filter_input_type=0&channel=EXPLORE&category_tag=Tag%3A8536&search_type=category_change"

# %%
r=requests.get(url)
print(r)
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(r.text,"lxml")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...
