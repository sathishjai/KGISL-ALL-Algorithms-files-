# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %% [markdown]
# ### Data Understanding

# %%
df=pd.read_csv("/home/sathish/Downloads/day (1).csv")

# %%
df
# Out:
#      instant      dteday  season  yr  ...  windspeed  casual  registered   cnt
# 0          1  01-01-2018       1   0  ...  10.749882     331         654   985
# 1          2  02-01-2018       1   0  ...  16.652113     131         670   801
# 2          3  03-01-2018       1   0  ...  16.636703     120        1229  1349
# 3          4  04-01-2018       1   0  ...  10.739832     108        1454  1562
# 4          5  05-01-2018       1   0  ...  12.522300      82        1518  1600
# ..       ...         ...     ...  ..  ...        ...     ...         ...   ...
# 725      726  27-12-2019       1   1  ...  23.458911     247        1867  2114
# 726      727  28-12-2019       1   1  ...  10.416557     644        2451  3095
# 727      728  29-12-2019       1   1  ...   8.333661     159        1182  1341
# 728      729  30-12-2019       1   1  ...  23.500518     364        1432  1796
# 729      730  31-12-2019       1   1  ...  10.374682     439        2290  2729
#
# [730 rows x 16 columns]

# %%
df.head(20)
# Out:
#     instant      dteday  season  yr  ...  windspeed  casual  registered   cnt
# 0         1  01-01-2018       1   0  ...  10.749882     331         654   985
# 1         2  02-01-2018       1   0  ...  16.652113     131         670   801
# 2         3  03-01-2018       1   0  ...  16.636703     120        1229  1349
# 3         4  04-01-2018       1   0  ...  10.739832     108        1454  1562
# 4         5  05-01-2018       1   0  ...  12.522300      82        1518  1600
# 5         6  06-01-2018       1   0  ...   6.000868      88        1518  1606
# 6         7  07-01-2018       1   0  ...  11.304642     148        1362  1510
# 7         8  08-01-2018       1   0  ...  17.875868      68         891   959
# 8         9  09-01-2018       1   0  ...  24.250650      54         768   822
# 9        10  10-01-2018       1   0  ...  14.958889      41        1280  1321
# 10       11  11-01-2018       1   0  ...   8.182844      43        1220  1263
# 11       12  12-01-2018       1   0  ...  20.410009      25        1137  1162
# 12       13  13-01-2018       1   0  ...  20.167000      38        1368  1406
# 13       14  14-01-2018       1   0  ...   8.478716      54        1367  1421
# 14       15  15-01-2018       1   0  ...  10.583521     222        1026  1248
# 15       16  16-01-2018       1   0  ...  12.625011     251         953  1204
# 16       17  17-01-2018       1   0  ...  12.999139     117         883  1000
# 17       18  18-01-2018       1   0  ...   9.833925       9         674   683
# 18       19  19-01-2018       1   0  ...  13.957239      78        1572  1650
# 19       20  20-01-2018       1   0  ...  13.125568      83        1844  1927
#
# [20 rows x 16 columns]

# %%
df.tail(2)
# Out:
#      instant      dteday  season  yr  ...  windspeed  casual  registered   cnt
# 728      729  30-12-2019       1   1  ...  23.500518     364        1432  1796
# 729      730  31-12-2019       1   1  ...  10.374682     439        2290  2729
#
# [2 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ### Basic information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
df.shape
# Out:
# (730, 16)

# %%
'instant','dteday','season','yr','mnth','holiday','weekday','workingday','weathersit','temp','atemp','hum','windspeed','casual','registered','cnt'
# Out:
# ('instant',
#  'dteday',
#  'season',
#  'yr',
#  'mnth',
#  'holiday',
#  'weekday',
#  'workingday',
#  'weathersit',
#  'temp',
#  'atemp',
#  'hum',
#  'windspeed',
#  'casual',
#  'registered',
#  'cnt')

# %% [markdown]
# ### Unique value for every columns

# %%
columns_to_impute=['instant','dteday','season','yr','mnth','holiday','weekday','workingday','weathersit','temp','atemp','hum','windspeed','casual','registered','cnt']
for i in columns_to_impute:
    print("how many unique value for ",i," : ",df[i].nunique())
# Out:
# how many unique value for  instant  :  730
# how many unique value for  dteday  :  730
# how many unique value for  season  :  4
# how many unique value for  yr  :  2
# how many unique value for  mnth  :  12
# how many unique value for  holiday  :  2
# how many unique value for  weekday  :  7
# how many unique value for  workingday  :  2
# how many unique value for  weathersit  :  3
# how many unique value for  temp  :  498
# how many unique value for  atemp  :  689
# how many unique value for  hum  :  594
# how many unique value for  windspeed  :  649
# how many unique value for  casual  :  605
# how many unique value for  registered  :  678
# how many unique value for  cnt  :  695

# %%
varlist=['season']

def binary_map(x):
    return x.map({1:"Spring",2:"Summer",3:"Fall",4:"Winter"})
df[varlist]=df[varlist].apply(binary_map)

# %%
varlist=['weathersit']

def binary_map(x):
    return x.map({1:"Clear",2:"Misty",3:"Light Snow or Rain",4:"Heavy Snow or Rain"})
df[varlist]=df[varlist].apply(binary_map)

# %%
df
# Out:
#      instant      dteday  season  yr  ...  windspeed  casual  registered   cnt
# 0          1  01-01-2018  Spring   0  ...  10.749882     331         654   985
# 1          2  02-01-2018  Spring   0  ...  16.652113     131         670   801
# 2          3  03-01-2018  Spring   0  ...  16.636703     120        1229  1349
# 3          4  04-01-2018  Spring   0  ...  10.739832     108        1454  1562
# 4          5  05-01-2018  Spring   0  ...  12.522300      82        1518  1600
# ..       ...         ...     ...  ..  ...        ...     ...         ...   ...
# 725      726  27-12-2019  Spring   1  ...  23.458911     247        1867  2114
# 726      727  28-12-2019  Spring   1  ...  10.416557     644        2451  3095
# 727      728  29-12-2019  Spring   1  ...   8.333661     159        1182  1341
# 728      729  30-12-2019  Spring   1  ...  23.500518     364        1432  1796
# 729      730  31-12-2019  Spring   1  ...  10.374682     439        2290  2729
#
# [730 rows x 16 columns]

# %%
varlist=['season']

def binary_map(x):
    return x.map({"Spring":0,"Summer":1,"Fall":2,"Winter":3})
df[varlist]=df[varlist].apply(binary_map)

# %%
varlist=['weathersit']

def binary_map(x):
    return x.map({"Clear":0,"Misty":1,"Light Snow or Rain":2,"Heavy Snow or Rain":3})
df[varlist]=df[varlist].apply(binary_map)

# %%
df
# Out:
#      instant      dteday  season  yr  ...  windspeed  casual  registered   cnt
# 0          1  01-01-2018       0   0  ...  10.749882     331         654   985
# 1          2  02-01-2018       0   0  ...  16.652113     131         670   801
# 2          3  03-01-2018       0   0  ...  16.636703     120        1229  1349
# 3          4  04-01-2018       0   0  ...  10.739832     108        1454  1562
# 4          5  05-01-2018       0   0  ...  12.522300      82        1518  1600
# ..       ...         ...     ...  ..  ...        ...     ...         ...   ...
# 725      726  27-12-2019       0   1  ...  23.458911     247        1867  2114
# 726      727  28-12-2019       0   1  ...  10.416557     644        2451  3095
# 727      728  29-12-2019       0   1  ...   8.333661     159        1182  1341
# 728      729  30-12-2019       0   1  ...  23.500518     364        1432  1796
# 729      730  31-12-2019       0   1  ...  10.374682     439        2290  2729
#
# [730 rows x 16 columns]

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
df['mnth'] = label_encoder.fit_transform(df['mnth'])

# %%
df
# Out:
#      instant      dteday  season  yr  ...  windspeed  casual  registered   cnt
# 0          1  01-01-2018       0   0  ...  10.749882     331         654   985
# 1          2  02-01-2018       0   0  ...  16.652113     131         670   801
# 2          3  03-01-2018       0   0  ...  16.636703     120        1229  1349
# 3          4  04-01-2018       0   0  ...  10.739832     108        1454  1562
# 4          5  05-01-2018       0   0  ...  12.522300      82        1518  1600
# ..       ...         ...     ...  ..  ...        ...     ...         ...   ...
# 725      726  27-12-2019       0   1  ...  23.458911     247        1867  2114
# 726      727  28-12-2019       0   1  ...  10.416557     644        2451  3095
# 727      728  29-12-2019       0   1  ...   8.333661     159        1182  1341
# 728      729  30-12-2019       0   1  ...  23.500518     364        1432  1796
# 729      730  31-12-2019       0   1  ...  10.374682     439        2290  2729
#
# [730 rows x 16 columns]

# %% [markdown]
# ### Missing values in the dataset

# %%
df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ### Describe value for Numerical columns

# %%
df.describe()
# Out:
#           instant      season  ...   registered          cnt
# count  730.000000  730.000000  ...   730.000000   730.000000
# mean   365.500000    1.498630  ...  3658.757534  4508.006849
# std    210.877136    1.110184  ...  1559.758728  1936.011647
# min      1.000000    0.000000  ...    20.000000    22.000000
# 25%    183.250000    1.000000  ...  2502.250000  3169.750000
# 50%    365.500000    2.000000  ...  3664.500000  4548.500000
# 75%    547.750000    2.000000  ...  4783.250000  5966.000000
# max    730.000000    3.000000  ...  6946.000000  8714.000000
#
# [8 rows x 15 columns]

# %% [markdown]
# ### Drop the unwanted columns

# %%
columns_to_drop = ["instant","dteday","casual"]
df=df.drop(columns=[col for col in columns_to_drop if col in df.columns])

# %%
df
# Out:
#      season  yr  mnth  holiday  ...      hum  windspeed  registered   cnt
# 0         0   0     0        0  ...  80.5833  10.749882         654   985
# 1         0   0     0        0  ...  69.6087  16.652113         670   801
# 2         0   0     0        0  ...  43.7273  16.636703        1229  1349
# 3         0   0     0        0  ...  59.0435  10.739832        1454  1562
# 4         0   0     0        0  ...  43.6957  12.522300        1518  1600
# ..      ...  ..   ...      ...  ...      ...        ...         ...   ...
# 725       0   1    11        0  ...  65.2917  23.458911        1867  2114
# 726       0   1    11        0  ...  59.0000  10.416557        2451  3095
# 727       0   1    11        0  ...  75.2917   8.333661        1182  1341
# 728       0   1    11        0  ...  48.3333  23.500518        1432  1796
# 729       0   1    11        0  ...  57.7500  10.374682        2290  2729
#
# [730 rows x 13 columns]

# %% [markdown]
# ### Heatmap

# %%
correlation_matrix=df.corr()
plt.figure(figsize=(12,8))
sns.heatmap(correlation_matrix,annot=True, cmap='Reds')
plt.title("Correlation Matrix")
plt.show()

# %%
sns.pairplot(df)

# %%
x=df[['season','yr','mnth','holiday','weekday','workingday','weathersit','temp','atemp','hum','windspeed','registered','cnt']]

# %% [markdown]
# ### Check for Outliers

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
sns.boxplot(x)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,30))
for i in range(len(x.columns)):
    plt.subplot(8,3,i+1)
    sns.boxplot(y=x.columns[i],data=x)
plt.show()

# %%
sns.distplot(df['cnt'])
plt.show()
# Out:
# /tmp/ipykernel_4737/3095626935.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cnt'])

# %%
fig=plt.figure()
plt.scatter(df['temp'],df['atemp'])
fig.suptitle('temp vs atemp',fontsize=18)
plt.xlabel('temp',fontsize=16)
plt.ylabel('atemp',fontsize=16)
plt.show()

# %%
fig=plt.figure()
plt.scatter(df['temp'],df['cnt'])
fig.suptitle('temp vs cnt',fontsize=18)
plt.xlabel('temp',fontsize=16)
plt.ylabel('cnt',fontsize=16)
plt.show()

# %%
fig=plt.figure()
plt.scatter(df['registered'],df['cnt'])
fig.suptitle('registered vs cnt',fontsize=18)
plt.xlabel('registered',fontsize=16)
plt.ylabel('cnt',fontsize=16)
plt.show()

# %% [markdown]
# ## Model Building

# %%
df.head()
# Out:
#    season  yr  mnth  holiday  ...      hum  windspeed  registered   cnt
# 0       0   0     0        0  ...  80.5833  10.749882         654   985
# 1       0   0     0        0  ...  69.6087  16.652113         670   801
# 2       0   0     0        0  ...  43.7273  16.636703        1229  1349
# 3       0   0     0        0  ...  59.0435  10.739832        1454  1562
# 4       0   0     0        0  ...  43.6957  12.522300        1518  1600
#
# [5 rows x 13 columns]

# %%
df.shape
# Out:
# (730, 13)

# %%
from sklearn.model_selection import train_test_split
df_train,df_test=train_test_split(df,train_size=0.7,test_size=0.3,random_state=42)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# ### manual feature selection

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
y_train=df_train.pop('cnt')
x_train=df_train

# %%
import statsmodels.api as sm
x_train=sm.add_constant(df_train)

# %%
x_train
# Out:
#      const  season  yr  mnth  ...     atemp      hum  windspeed  registered
# 683    1.0       3   1    10  ...  16.22460  62.0417  10.250129        5125
# 645    1.0       3   1     9  ...  19.38040  70.9583  12.708493        4604
# 163    1.0       1   0     5  ...  30.08270  49.4583  20.458450        4157
# 360    1.0       0   0    11  ...  16.38165  76.2500  12.626150        1059
# 640    1.0       3   1     9  ...  29.95665  79.3750   4.458569        6844
# ..     ...     ...  ..   ...  ...       ...      ...        ...         ...
# 700    1.0       3   1    11  ...  17.96040  82.3333   8.333393        3757
# 71     1.0       0   0     2  ...  19.00455  52.7391  18.130468        1435
# 106    1.0       1   0     3  ...  22.28480  47.9583  20.334232        2186
# 270    1.0       3   0     8  ...  28.75790  84.8750   9.958143        3427
# 435    1.0       0   1     2  ...  22.97960  48.9167  13.916771        4460
#
# [510 rows x 13 columns]

# %%
lm=sm.OLS(y_train,x_train).fit()
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.964
# Method:                 Least Squares   F-statistic:                     1126.
# Date:                Wed, 07 Aug 2024   Prob (F-statistic):               0.00
# Time:                        10:17:36   Log-Likelihood:                -3732.0
# No. Observations:                 510   AIC:                             7490.
# Df Residuals:                     497   BIC:                             7545.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        366.5324    139.872      2.620      0.009      91.720     641.345
# season        -5.2182     30.493     -0.171      0.864     -65.129      54.692
# yr           -31.7214     53.136     -0.597      0.551    -136.121      72.678
# mnth         -11.5139      8.823     -1.305      0.193     -28.850       5.822
# holiday     -200.0859    104.595     -1.913      0.056    -405.589       5.417
# weekday       21.2276      8.167      2.599      0.010       5.181      37.274
# workingday  -982.2164     42.958    -22.865      0.000   -1066.618    -897.815
# weathersit   -20.5622     40.533     -0.507      0.612    -100.199      59.074
# temp         -34.9799     28.185     -1.241      0.215     -90.356      20.396
# atemp         64.9387     26.312      2.468      0.014      13.243     116.634
# hum           -3.7399      1.602     -2.334      0.020      -6.888      -0.592
# windspeed     -5.0464      3.755     -1.344      0.180     -12.424       2.332
# registered     1.1758      0.024     48.460      0.000       1.128       1.223
# ==============================================================================
# Omnibus:                       95.031   Durbin-Watson:                   2.105
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              209.586
# Skew:                           0.987   Prob(JB):                     3.08e-46
# Kurtosis:                       5.442   Cond. No.                     3.51e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.51e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
vif=pd.DataFrame()
vif['features']=x_train.columns
vif['VIF']=[variance_inflation_factor(x_train.values,i)for i in range(x_train.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by='VIF',ascending=False)
vif
# Out:
#       features     VIF
# 9        atemp  170.35
# 8         temp  166.01
# 0        const   73.17
# 12  registered    5.44
# 1       season    4.22
# 3         mnth    3.40
# 2           yr    2.63
# 10         hum    1.86
# 7   weathersit    1.84
# 6   workingday    1.53
# 11   windspeed    1.30
# 4      holiday    1.09
# 5      weekday    1.03

# %%
columns_to_drop = ["atemp"]
x_train = x_train.drop(columns=[col for col in columns_to_drop if col in x_train.columns])
lm=sm.OLS(y_train,x_train).fit()
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.964
# Model:                            OLS   Adj. R-squared:                  0.963
# Method:                 Least Squares   F-statistic:                     1216.
# Date:                Wed, 07 Aug 2024   Prob (F-statistic):               0.00
# Time:                        10:17:36   Log-Likelihood:                -3735.1
# No. Observations:                 510   AIC:                             7494.
# Df Residuals:                     498   BIC:                             7545.
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        494.5889    130.555      3.788      0.000     238.083     751.095
# season        -3.6934     30.642     -0.121      0.904     -63.897      56.510
# yr           -39.0102     53.325     -0.732      0.465    -143.779      65.759
# mnth         -11.4483      8.868     -1.291      0.197     -28.872       5.976
# holiday     -214.8298    104.957     -2.047      0.041    -421.042      -8.617
# weekday       20.9461      8.208      2.552      0.011       4.820      37.073
# workingday  -984.4281     43.168    -22.805      0.000   -1069.241    -899.615
# weathersit   -29.6388     40.571     -0.731      0.465    -109.351      50.073
# temp          34.1668      3.092     11.049      0.000      28.091      40.242
# hum           -3.2909      1.600     -2.057      0.040      -6.434      -0.148
# windspeed     -7.3546      3.655     -2.012      0.045     -14.537      -0.173
# registered     1.1807      0.024     48.576      0.000       1.133       1.228
# ==============================================================================
# Omnibus:                       98.370   Durbin-Watson:                   2.127
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              216.070
# Skew:                           1.022   Prob(JB):                     1.21e-47
# Kurtosis:                       5.448   Cond. No.                     3.25e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.25e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
vif=pd.DataFrame()
vif['features']=x_train.columns
vif['VIF']=[variance_inflation_factor(x_train.values,i)for i in range(x_train.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by='VIF',ascending=False)
vif
# Out:
#       features    VIF
# 0        const  63.10
# 11  registered   5.40
# 1       season   4.22
# 3         mnth   3.40
# 2           yr   2.63
# 8         temp   1.98
# 7   weathersit   1.83
# 9          hum   1.83
# 6   workingday   1.53
# 10   windspeed   1.22
# 4      holiday   1.09
# 5      weekday   1.03

# %%
columns_to_drop = ["const"]
x_train = x_train.drop(columns=[col for col in columns_to_drop if col in x_train.columns])
lm=sm.OLS(y_train,x_train).fit()
print(lm.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    cnt   R-squared (uncentered):                   0.994
# Model:                            OLS   Adj. R-squared (uncentered):              0.994
# Method:                 Least Squares   F-statistic:                              7991.
# Date:                Wed, 07 Aug 2024   Prob (F-statistic):                        0.00
# Time:                        10:17:36   Log-Likelihood:                         -3742.3
# No. Observations:                 510   AIC:                                      7507.
# Df Residuals:                     499   BIC:                                      7553.
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# season       -16.8110     30.850     -0.545      0.586     -77.423      43.801
# yr           -33.1357     54.010     -0.614      0.540    -139.251      72.980
# mnth          -7.4873      8.924     -0.839      0.402     -25.020      10.045
# holiday     -166.1459    105.551     -1.574      0.116    -373.526      41.234
# weekday       27.9059      8.106      3.443      0.001      11.980      43.832
# workingday  -968.8984     43.544    -22.251      0.000   -1054.450    -883.347
# weathersit   -82.7552     38.578     -2.145      0.032    -158.550      -6.961
# temp          35.2450      3.120     11.296      0.000      29.115      41.375
# hum            1.3020      1.058      1.231      0.219      -0.776       3.380
# windspeed      1.5257      2.842      0.537      0.592      -4.058       7.110
# registered     1.1930      0.024     48.871      0.000       1.145       1.241
# ==============================================================================
# Omnibus:                      105.034   Durbin-Watson:                   2.125
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              238.689
# Skew:                           1.073   Prob(JB):                     1.48e-52
# Kurtosis:                       5.574   Cond. No.                     2.56e+04
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 2.56e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
vif=pd.DataFrame()
vif['features']=x_train.columns
vif['VIF']=[variance_inflation_factor(x_train.values,i)for i in range(x_train.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by='VIF',ascending=False)
vif
# Out:
#       features    VIF
# 10  registered  34.68
# 8          hum  17.02
# 7         temp  16.80
# 2         mnth  12.33
# 0       season  12.21
# 1           yr   5.49
# 9    windspeed   5.33
# 5   workingday   4.57
# 4      weekday   3.07
# 6   weathersit   2.48
# 3      holiday   1.10

# %%
columns_to_drop = ["registered"]
x_train = x_train.drop(columns=[col for col in columns_to_drop if col in x_train.columns])
lm=sm.OLS(y_train,x_train).fit()
print(lm.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    cnt   R-squared (uncentered):                   0.967
# Model:                            OLS   Adj. R-squared (uncentered):              0.967
# Method:                 Least Squares   F-statistic:                              1481.
# Date:                Wed, 07 Aug 2024   Prob (F-statistic):                        0.00
# Time:                        10:17:36   Log-Likelihood:                         -4190.0
# No. Observations:                 510   AIC:                                      8400.
# Df Residuals:                     500   BIC:                                      8442.
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# season       566.4209     68.364      8.285      0.000     432.105     700.737
# yr          2061.0753     79.004     26.088      0.000    1905.854    2216.297
# mnth         -46.2676     21.359     -2.166      0.031     -88.232      -4.303
# holiday     -384.8331    253.420     -1.519      0.130    -882.733     113.066
# weekday       78.3357     19.321      4.054      0.000      40.375     116.296
# workingday   228.5048     86.502      2.642      0.009      58.553     398.457
# weathersit  -757.9015     86.557     -8.756      0.000    -927.962    -587.841
# temp         133.0082      5.754     23.115      0.000     121.703     144.314
# hum            3.0229      2.540      1.190      0.235      -1.968       8.014
# windspeed    -11.3190      6.801     -1.664      0.097     -24.680       2.042
# ==============================================================================
# Omnibus:                       44.131   Durbin-Watson:                   2.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               70.681
# Skew:                          -0.591   Prob(JB):                     4.49e-16
# Kurtosis:                       4.389   Cond. No.                         442.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
vif=pd.DataFrame()
vif['features']=x_train.columns
vif['VIF']=[variance_inflation_factor(x_train.values,i)for i in range(x_train.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by='VIF',ascending=False)
vif
# Out:
#      features    VIF
# 8         hum  17.00
# 2        mnth  12.23
# 0      season  10.38
# 7        temp   9.89
# 9   windspeed   5.29
# 5  workingday   3.12
# 4     weekday   3.02
# 6  weathersit   2.16
# 1          yr   2.03
# 3     holiday   1.10

# %%
columns_to_drop = ["hum"]
x_train = x_train.drop(columns=[col for col in columns_to_drop if col in x_train.columns])
lm=sm.OLS(y_train,x_train).fit()
print(lm.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    cnt   R-squared (uncentered):                   0.967
# Model:                            OLS   Adj. R-squared (uncentered):              0.967
# Method:                 Least Squares   F-statistic:                              1644.
# Date:                Wed, 07 Aug 2024   Prob (F-statistic):                        0.00
# Time:                        10:17:36   Log-Likelihood:                         -4190.7
# No. Observations:                 510   AIC:                                      8399.
# Df Residuals:                     501   BIC:                                      8437.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# season       560.1658     68.190      8.215      0.000     426.193     694.139
# yr          2065.8380     78.936     26.171      0.000    1910.752    2220.924
# mnth         -40.0523     20.719     -1.933      0.054     -80.759       0.654
# holiday     -343.5928    251.143     -1.368      0.172    -837.016     149.830
# weekday       82.3133     19.037      4.324      0.000      44.910     119.716
# workingday   248.7212     84.852      2.931      0.004      82.011     415.431
# weathersit  -703.2892     73.417     -9.579      0.000    -847.532    -559.046
# temp         136.6150      4.893     27.920      0.000     127.002     146.228
# windspeed     -8.5818      6.402     -1.340      0.181     -21.161       3.997
# ==============================================================================
# Omnibus:                       48.055   Durbin-Watson:                   2.064
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               77.752
# Skew:                          -0.630   Prob(JB):                     1.31e-17
# Kurtosis:                       4.439   Cond. No.                         162.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
vif=pd.DataFrame()
vif['features']=x_train.columns
vif['VIF']=[variance_inflation_factor(x_train.values,i)for i in range(x_train.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by='VIF',ascending=False)
vif
# Out:
#      features    VIF
# 2        mnth  11.50
# 0      season  10.32
# 7        temp   7.15
# 8   windspeed   4.68
# 5  workingday   3.00
# 4     weekday   2.93
# 1          yr   2.03
# 6  weathersit   1.56
# 3     holiday   1.08

# %%
columns_to_drop = ["mnth"]
x_train = x_train.drop(columns=[col for col in columns_to_drop if col in x_train.columns])
lm=sm.OLS(y_train,x_train).fit()
print(lm.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    cnt   R-squared (uncentered):                   0.967
# Model:                            OLS   Adj. R-squared (uncentered):              0.966
# Method:                 Least Squares   F-statistic:                              1839.
# Date:                Wed, 07 Aug 2024   Prob (F-statistic):                        0.00
# Time:                        10:17:37   Log-Likelihood:                         -4192.6
# No. Observations:                 510   AIC:                                      8401.
# Df Residuals:                     502   BIC:                                      8435.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# season       451.3537     38.595     11.695      0.000     375.527     527.180
# yr          2055.9346     78.984     26.030      0.000    1900.755    2211.114
# holiday     -398.5807    250.206     -1.593      0.112    -890.161      92.999
# weekday       79.7098     19.041      4.186      0.000      42.299     117.121
# workingday   241.8729     85.009      2.845      0.005      74.856     408.890
# weathersit  -717.6778     73.237     -9.799      0.000    -861.567    -573.788
# temp         136.2095      4.902     27.787      0.000     126.579     145.840
# windspeed    -10.1915      6.365     -1.601      0.110     -22.697       2.314
# ==============================================================================
# Omnibus:                       45.954   Durbin-Watson:                   2.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               72.884
# Skew:                          -0.615   Prob(JB):                     1.49e-16
# Kurtosis:                       4.385   Cond. No.                         157.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
vif=pd.DataFrame()
vif['features']=x_train.columns
vif['VIF']=[variance_inflation_factor(x_train.values,i)for i in range(x_train.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by='VIF',ascending=False)
vif
# Out:
#      features   VIF
# 6        temp  7.13
# 7   windspeed  4.60
# 0      season  3.29
# 4  workingday  3.00
# 3     weekday  2.91
# 1          yr  2.02
# 5  weathersit  1.54
# 2     holiday  1.07

# %%
columns_to_drop = ["temp"]
x_train = x_train.drop(columns=[col for col in columns_to_drop if col in x_train.columns])
lm=sm.OLS(y_train,x_train).fit()
print(lm.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    cnt   R-squared (uncentered):                   0.916
# Model:                            OLS   Adj. R-squared (uncentered):              0.915
# Method:                 Least Squares   F-statistic:                              786.1
# Date:                Wed, 07 Aug 2024   Prob (F-statistic):                   3.37e-266
# Time:                        10:17:37   Log-Likelihood:                         -4430.1
# No. Observations:                 510   AIC:                                      8874.
# Df Residuals:                     503   BIC:                                      8904.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# season       989.3092     53.139     18.617      0.000     884.908    1093.710
# yr          2408.7597    124.073     19.414      0.000    2164.995    2652.524
# holiday      114.7777    397.132      0.289      0.773    -665.464     895.020
# weekday      181.7377     29.737      6.112      0.000     123.314     240.162
# workingday   961.0323    128.875      7.457      0.000     707.834    1214.231
# weathersit  -788.9008    116.491     -6.772      0.000   -1017.769    -560.033
# windspeed     59.7461      9.305      6.421      0.000      41.464      78.028
# ==============================================================================
# Omnibus:                       17.308   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.198
# Skew:                          -0.300   Prob(JB):                     5.56e-06
# Kurtosis:                       3.882   Cond. No.                         86.6
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
vif=pd.DataFrame()
vif['features']=x_train.columns
vif['VIF']=[variance_inflation_factor(x_train.values,i)for i in range(x_train.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by='VIF',ascending=False)
vif
# Out:
#      features   VIF
# 6   windspeed  3.88
# 3     weekday  2.81
# 4  workingday  2.72
# 0      season  2.46
# 1          yr  1.97
# 5  weathersit  1.54
# 2     holiday  1.06

# %%
columns_to_drop = ["holiday"]
x_train = x_train.drop(columns=[col for col in columns_to_drop if col in x_train.columns])
lm=sm.OLS(y_train,x_train).fit()
print(lm.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    cnt   R-squared (uncentered):                   0.916
# Model:                            OLS   Adj. R-squared (uncentered):              0.915
# Method:                 Least Squares   F-statistic:                              918.8
# Date:                Wed, 07 Aug 2024   Prob (F-statistic):                   1.11e-267
# Time:                        10:17:37   Log-Likelihood:                         -4430.1
# No. Observations:                 510   AIC:                                      8872.
# Df Residuals:                     504   BIC:                                      8898.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# season       990.3002     52.980     18.692      0.000     886.212    1094.389
# yr          2411.3071    123.647     19.502      0.000    2168.381    2654.233
# weekday      181.3910     29.686      6.110      0.000     123.068     239.714
# workingday   954.6046    126.826      7.527      0.000     705.433    1203.777
# weathersit  -788.9692    116.385     -6.779      0.000   -1017.628    -560.311
# windspeed     60.1211      9.206      6.531      0.000      42.034      78.208
# ==============================================================================
# Omnibus:                       17.317   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.361
# Skew:                          -0.298   Prob(JB):                     5.13e-06
# Kurtosis:                       3.889   Cond. No.                         28.7
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
vif=pd.DataFrame()
vif['features']=x_train.columns
vif['VIF']=[variance_inflation_factor(x_train.values,i)for i in range(x_train.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by='VIF',ascending=False)
vif
# Out:
#      features   VIF
# 5   windspeed  3.81
# 2     weekday  2.80
# 3  workingday  2.64
# 0      season  2.45
# 1          yr  1.96
# 4  weathersit  1.54

# %%
columns_to_drop = ["weathersit"]
x_train = x_train.drop(columns=[col for col in columns_to_drop if col in x_train.columns])
lm=sm.OLS(y_train,x_train).fit()
print(lm.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    cnt   R-squared (uncentered):                   0.909
# Model:                            OLS   Adj. R-squared (uncentered):              0.908
# Method:                 Least Squares   F-statistic:                              1004.
# Date:                Wed, 07 Aug 2024   Prob (F-statistic):                   1.16e-259
# Time:                        10:17:37   Log-Likelihood:                         -4452.4
# No. Observations:                 510   AIC:                                      8915.
# Df Residuals:                     505   BIC:                                      8936.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# season       960.8160     55.101     17.437      0.000     852.561    1069.071
# yr          2395.8492    129.011     18.571      0.000    2142.385    2649.313
# weekday      170.4440     30.933      5.510      0.000     109.671     231.217
# workingday   891.8711    131.997      6.757      0.000     632.539    1151.203
# windspeed     45.8570      9.353      4.903      0.000      27.482      64.232
# ==============================================================================
# Omnibus:                       21.845   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.014
# Skew:                          -0.448   Prob(JB):                     3.70e-06
# Kurtosis:                       3.613   Cond. No.                         28.6
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
vif=pd.DataFrame()
vif['features']=x_train.columns
vif['VIF']=[variance_inflation_factor(x_train.values,i)for i in range(x_train.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by='VIF',ascending=False)
vif
# Out:
#      features   VIF
# 4   windspeed  3.61
# 2     weekday  2.79
# 3  workingday  2.63
# 0      season  2.43
# 1          yr  1.96

# %%
y_train
# Out:
# 683    5445
# 645    5478
# 163    5020
# 360    1162
# 640    7572
#        ...
# 700    4649
# 71     2417
# 106    3744
# 270    3907
# 435    5298
# Name: cnt, Length: 510, dtype: int64

# %%
x_train
# Out:
#      season  yr  weekday  workingday  windspeed
# 683       3   1        4           1  10.250129
# 645       3   1        1           0  12.708493
# 163       1   0        1           1  20.458450
# 360       0   0        2           1  12.626150
# 640       3   1        3           1   4.458569
# ..      ...  ..      ...         ...        ...
# 700       3   1        0           0   8.333393
# 71        0   0        0           0  18.130468
# 106       1   0        0           0  20.334232
# 270       3   0        3           1   9.958143
# 435       0   1        1           1  13.916771
#
# [510 rows x 5 columns]

# %%
# model evaluation
y_pred_train=lm.predict(x_train)

# %%
#mean squared error and R-squared for model evaluation
mse_train=mean_squared_error(y_train,y_pred_train)
r2_train=r2_score(y_train,y_pred_train)

# %%
print(mse_train)
print(r2_train)
# Out:
# 2241109.7362298076
# 0.4017806664719471

# %%
x_test=df_test[['season','weekday','yr','workingday','windspeed']]
y_test=df_test[['cnt']]

# %%
# model evaluation
y_pred_test=lm.predict(x_test)

# %%
columns_to_drop = ["const"]
df=x_test_sm.drop(columns=[col for col in columns_to_drop if col in x_test_sm.columns])

# %%
#mean squared error and R-squared for model evaluation
mse_train=mean_squared_error(y_test,y_pred_)
r2_train=r2_score(y_test,y_pred_train)
print(mse_test)
print(r2_test,"\n")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 2
#       1 #mean squared error and R-squared for model evaluation
# ----> 2 mse_train=mean_squared_error(y_test,y_pred_train)
#       3 r2_train=r2_score(y_test,y_pred_train)
#       4 print(mse_test)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:497, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     492     if not squared:
#     493         return root_mean_squared_error(
#     494             y_true, y_pred, sample_weight=sample_weight, multioutput=multioutput
#     495         )
# --> 497 y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     498     y_true, y_pred, multioutput
#     499 )
#     500 check_consistent_length(y_true, y_pred, sample_weight)
#     501 output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:102, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      68 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      69     """Check that y_true and y_pred belong to the same regression task.
#      70
#      71     Parameters
#    (...)
#     100         correct keyword.
#     101     """
# --> 102     check_consistent_length(y_true, y_pred)
#     103     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     104     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:457, in check_consistent_length(*arrays)
#     455 uniques = np.unique(lengths)
#     456 if len(uniques) > 1:
# --> 457     raise ValueError(
#     458         "Found input variables with inconsistent numbers of samples: %r"
#     459         % [int(l) for l in lengths]
#     460     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [219, 510]

# %%
import statsmodels.api as sm

# %%
import statsmodels.api as sm

# %% [markdown]
# ## RFE method

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv("/home/sathish/Downloads/day (1).csv")

# %%
varlist=['season']

def binary_map(x):
    return x.map({1:"Spring",2:"Summer",3:"Fall",4:"Winter"})
df[varlist]=data[varlist].apply(binary_map)

# %%
varlist=['weathersit']

def binary_map(x):
    return x.map({1:"Clear",2:"Misty",3:"Light Snow or Rain",4:"Heavy Snow or Rain"})
df[varlist]=data[varlist].apply(binary_map)

# %%
varlist=['season']

def binary_map(x):
    return x.map({"Spring":0,"Summer":1,"Fall":2,"Winter":3})
df[varlist]=data[varlist].apply(binary_map)

# %%
varlist=['weathersit']

def binary_map(x):
    return x.map({"Clear":0,"Misty":1,"Light Snow or Rain":2,"Heavy Snow or Rain":3})
df[varlist]=data[varlist].apply(binary_map)

# %%
columns_to_drop = ["instant","dteday","casual"]
data1=data.drop(columns=[col for col in columns_to_drop if col in data.columns])

# %%
data1

# %%
from sklearn.model_selection import train_test_split
df_train,df_test=train_test_split(data1,train_size=0.7,test_size=0.3,random_state=42)

# %%
y_train2=df_train.pop('cnt')
x_train2=df_train

# %%
lm1=LinearRegression()
lm1.fit(x_train2,y_train2)
rfe1=RFE(estimator=lm1,n_features_to_select=7)
rfe1=rfe1.fit(x_train2,y_train2)

# %%
list(zip(x_train2.columns,rfe1.support_,rfe1.ranking_))

# %%
col=x_train2.columns[rfe1.support_]
col

# %%
x_train1=x_train2[col]

# %%
import statsmodels.api as sm
x_train_rfe=sm.add_constant(x_train1)
x_train_rfe

# %%
lm1=sm.OLS(y_train2,x_train_rfe).fit()

# %%
print(lm1.summary())

# %%
y_train_pred=lm1.predict(x_train_rfe)

# %%
np.sqrt(mean_squared_error(y_train,y_train_pred))

# %%
y_train

# %%
y_train_pred

# %%
r_squared=r2_score(y_train,y_train_pred)
r_squared

# %%
#mean squared error and R-squared for model evaluation
mse=mean_squared_error(y_train,y_train_pred)
r2=r2_score(y_train,y_train_pred)

# %%
r2
